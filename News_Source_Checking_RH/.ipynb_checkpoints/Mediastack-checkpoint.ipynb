# %% [markdown]
# ### API Links
#
# ##### -https://mediastack.com/documentation

# %% [markdown]
# ### Pricing
# ###### -https://mediastack.com/pricing

# %% [markdown]
# ![image.png](attachment:26a13cb4-6e05-4950-b1e0-5521d6003228.png)

# %% [markdown]
# ### Sample Pulls

# %%
https://api.mediastack.com/v1/news?access_key=ee42848c673648e1635c3a6e40811334&keywords=virus,-corona

# %%
import http.client, urllib.parse

conn = http.client.HTTPConnection('api.mediastack.com')

params = urllib.parse.urlencode({
    'access_key': 'ee42848c673648e1635c3a6e40811334',
    'categories': '-general,-sports',
    'sort': 'published_desc',
    'limit': 100,'keywords':'aramco,saudi-aramco'
    })

conn.request('GET', '/v1/news?{}'.format(params))

res = conn.getresponse()
data = res.read()

print(data.decode('utf-8'))
# Out:
# {"pagination":{"limit":100,"offset":0,"count":100,"total":291},"data":[{"author":"Heena Ojha","title":"Castrol India Share Price Rises As Saudi Aramco Looks To Pick Up Stake","description":"Castrol India Share Price Rises As Saudi Aramco Looks To Pick Up Stake","url":"https:\/\/www.ndtvprofit.com\/markets\/castrol-india-share-price-rises-as-saudi-aramco-looks-to-pick-up-stake","source":"Bloomberg | Latest And Live Business","image":null,"category":"business","language":"en","country":"us","published_at":"2025-03-06T07:42:47+00:00"},{"author":"Bloomberg News","title":"Saudi Aramco Weighs Bid for BP\u2019s Castrol Lubricant Assets","description":"Saudi Aramco Weighs Bid for BP\u2019s Castrol Lubricant Assets","url":"https:\/\/www.ndtvprofit.com\/world\/saudi-aramco-weighs-bid-for-bps-castrol-lubricant-assets","source":"Bloomberg | Latest And Live Business","image":null,"category":"business","language":"en","country":"us","published_at":"2025-03-05T14:39:24+00:00"},{"author":"Mandy Dalu
# ...

# %%
data = data.decode('utf-8')

# %%
import pandas as pd
# Out:
# '{"pagination":{"limit":10,"offset":0,"count":10,"total":291},"data":[{"author":"Heena Ojha","title":"Castrol India Share Price Rises As Saudi Aramco Looks To Pick Up Stake","description":"Castrol India Share Price Rises As Saudi Aramco Looks To Pick Up Stake","url":"https:\\/\\/www.ndtvprofit.com\\/markets\\/castrol-india-share-price-rises-as-saudi-aramco-looks-to-pick-up-stake","source":"Bloomberg | Latest And Live Business","image":null,"category":"business","language":"en","country":"us","published_at":"2025-03-06T07:42:47+00:00"},{"author":"Bloomberg News","title":"Saudi Aramco Weighs Bid for BP\\u2019s Castrol Lubricant Assets","description":"Saudi Aramco Weighs Bid for BP\\u2019s Castrol Lubricant Assets","url":"https:\\/\\/www.ndtvprofit.com\\/world\\/saudi-aramco-weighs-bid-for-bps-castrol-lubricant-assets","source":"Bloomberg | Latest And Live Business","image":null,"category":"business","language":"en","country":"us","published_at":"2025-03-05T14:39:24+00:00"},{"author":"M
# ...

# %%
import json

# %%
data = json.loads(data)

data
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 291}, 'data': [{'author': 'Heena Ojha', 'title': 'Castrol India Share Price Rises As Saudi Aramco Looks To Pick Up Stake', 'description': 'Castrol India Share Price Rises As Saudi Aramco Looks To Pick Up Stake', 'url': 'https://www.ndtvprofit.com/markets/castrol-india-share-price-rises-as-saudi-aramco-looks-to-pick-up-stake', 'source': 'Bloomberg | Latest And Live Business', 'image': None, 'category': 'business', 'language': 'en', 'country': 'us', 'published_at': '2025-03-06T07:42:47+00:00'}, {'author': 'Bloomberg News', 'title': 'Saudi Aramco Weighs Bid for BP’s Castrol Lubricant Assets', 'description': 'Saudi Aramco Weighs Bid for BP’s Castrol Lubricant Assets', 'url': 'https://www.ndtvprofit.com/world/saudi-aramco-weighs-bid-for-bps-castrol-lubricant-assets', 'source': 'Bloomberg | Latest And Live Business', 'image': None, 'category': 'business', 'language': 'en', 'country': 'us', 'published_at': '2025-03-05T14:39:2
# ...

# %%
        # Extract the 'data' array from the JSON which contains the news articles
articles = data['data']

# %%
# Convert to DataFrame
df = pd.DataFrame(articles)
df
# Out:
#             author                                              title  ... country               published_at
# 0       Heena Ojha  Castrol India Share Price Rises As Saudi Aramc...  ...      us  2025-03-06T07:42:47+00:00
# 1   Bloomberg News  Saudi Aramco Weighs Bid for BP’s Castrol Lubri...  ...      us  2025-03-05T14:39:24+00:00
# 2   Mandy Dalugdug  Saudi Arabia’s MDLBEAST unveils ‘A Thousand An...  ...      us  2025-03-05T11:50:54+00:00
# 3   Bloomberg News  Saudi Aramco Weighs Bid for BP’s Castrol Lubri...  ...      us  2025-03-05T11:07:17+00:00
# 4    Business Wire  Zain KSA Completes Major Digital Transformatio...  ...      us  2025-03-04T11:10:23+00:00
# ..             ...                                                ...  ...     ...                        ...
# 95            None  Nvidia competitor Groq receives $1.5B commitme...  ...      us  2025-02-10T18:11:03+00:00
# ...
