# %% [markdown]
# # NewsAPI

# %% [markdown]
# #### Documentation
# ##### -https://newsdata.io/documentation

# %% [markdown]
# #### Pricing

# %% [markdown]
# ![image.png](attachment:b73e6252-5ce7-4bd8-b100-60dbb47808e9.png)

# %% [markdown]
# ##### -https://newsdata.io/pricing

# %%
from newsdataapi import NewsDataApiClient

# API key authorization, Initialize the client with your API key

api = NewsDataApiClient(apikey="pub_676734e5e12558dc51f2dd544b8a069165701")

# You can pass empty or with request parameters {ex. (country = "us")}

response = api.news_api( q= "aramco")
# Out:
# C:\Users\rajesh.hugar\AppData\Local\Temp\ipykernel_14108\1843325588.py:9: DeprecationWarning: This method is deprecated and will be removed in upcoming updates, Instead use latest_api()
#   response = api.news_api( q= "aramco")

# %%
response
# Out:
# {'status': 'success',
#  'totalResults': 192,
#  'results': [{'article_id': 'db06ee19e65bccbd3d512a4ee38d5e98',
#    'title': 'Le baril de pétrole sous la barre des 70 dollars, nouvelle référence du marché?',
#    'link': 'https://www.rfi.fr/fr/podcasts/chronique-des-mati%C3%A8res-premi%C3%A8res/20250305-le-baril-de-p%C3%A9trole-sous-la-barre-des-70-dollars-nouvelle-r%C3%A9f%C3%A9rence-du-march%C3%A9',
#    'keywords': ['chronique des matières premières'],
#    'creator': ['Marie-Pierre Olphand'],
#    'video_url': None,
#    'description': 'Les cours du pétrole ont dévissé depuis lundi 3 mars et sont passés largement sous la barre des 70 dollars — contre 80 dollars mi-janvier. Le déclencheur a été une annonce faite par plusieurs producteurs de pétrole, membres de l’Opep+, des pays qui depuis 2022 ont réduit leur production.',
#    'content': 'ONLY AVAILABLE IN PAID PLANS',
#    'pubDate': '2025-03-05 23:01:43',
#    'pubDateTZ': 'UTC',
#    'image_url': 'https://s.rfi.fr/media/display/2e664bf2-d9a4-11ee-a813-005056a97e36/w:1024/p:16x9/00aa9f1f08e7769ac8418aad2af33c3a357879d591f678783e30e194a9e4b8ff.png',
#    'source_id': 'rfi_fr',
#    'source_priority': 8490,
#    'source_name': 'Rfi',
#    'source_url': 'https://www.rfi.fr/en/france',
#    'source_icon': 'https://i.bytvi.com/domain_icons/rfi_fr.png',
#    'language': 'french',
#    'country': ['france'],
#    'category': ['business'],
#    'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'duplicate': False},
#   {'article_id': 'da92c4becee4759af5820806ebb4d6dd',
#    'title': 'Big Oil Goes Back to What It Does Best',
#    'link': 'https://oilprice.com/Energy/Energy-General/Big-Oil-Goes-Back-to-What-It-Does-Best.html',
#    'keywords': None,
#    'creator': ['Irina Slav'],
#    'video_url': None,
#    'description': 'At the 2024 edition of CERAWeek, several energy executives openly called for a rethink of the energy transition. That had never happened before. Before, everyone was on board with a move from oil and gas to electricity. Fast forward a year, and it’s official: Big Oil is done with the transition and is returning to what it does best—oil and gas. It was BP that put the period at the end of the industry’s attempts to transform into power companies making money by building and operating wind turbines and solar installations. This...',
#    'content': 'ONLY AVAILABLE IN PAID PLANS',
#    'pubDate': '2025-03-05 23:00:00',
#    'pubDateTZ': 'UTC',
#    'image_url': 'https://d32r1sh890xpii.cloudfront.net/article/718x300/2025-03-05_ubs1vuzmjn.jpg',
#    'source_id': 'oilprice',
#    'source_priority': 1511,
#    'source_name': 'Oil Price',
#    'source_url': 'https://oilprice.com',
#    'source_icon': 'https://i.bytvi.com/domain_icons/oilprice.png',
#    'language': 'english',
#    'country': ['united kingdom',
#     'united states of america',
#     'india',
#     'australia',
#     'singapore',
#     'saudi arabia',
#     'canada'],
#    'category': ['business'],
#    'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'duplicate': False},
#   {'article_id': '5c71b8bc515f2b9d725f1b55fb4b370b',
#    'title': 'Metade das emissões mundiais de CO2 vêm de 36 empresas de combustíveis fósseis, diz estudo',
#    'link': 'https://valor.globo.com/mundo/noticia/2025/03/05/metade-das-emisses-mundiais-de-co2-vm-de-36-empresas-de-combustveis-fsseis-diz-estudo.ghtml',
#    'keywords': ['valor'],
#    'creator': None,
#    'video_url': None,
#    'description': 'Se a Saudi Aramco fosse um país, seria o quarto ma...',
#    'content': 'ONLY AVAILABLE IN PAID PLANS',
#    'pubDate': '2025-03-05 21:17:07',
#    'pubDateTZ': 'UTC',
#    'image_url': 'https://s2-valor.glbimg.com/kofOkuB8QCs7Gi7fFjuaNYeiVUQ=/i.s3.glbimg.com/v1/AUTH_63b422c2caee4269b8b34177e8876b93/internal_photos/bs/2023/P/B/wkpREXQri142k6FsmEnw/abqaiq-20oil-20plant.jpg',
#    'source_id': 'valor_globo',
#    'source_priority': 2786,
#    'source_name': 'Valor Globo',
#    'source_url': 'https://valor.globo.com',
#    'source_icon': 'https://i.bytvi.com/domain_icons/valor_globo.png',
#    'language': 'portuguese',
#    'country': ['brazil'],
#    'category': ['top'],
#    'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'duplicate': False},
#   {'article_id': '816dbcdd01d45f9b23827329aaa289bb',
#    'title': 'Saudi green initiative: Lessons for Pakistan',
#    'link': 'https://pakobserver.net/saudi-green-initiative-lessons-for-pakistan/',
#    'keywords': ['article'],
#    'creator': ['News desk'],
#    'video_url': None,
#    'description': 'Adeela Naureen and Waqar K Kauravi THE Saudi Green Initiative (SGI), launched in 2021 by His Royal Highness Crown Prince...',
#    'content': 'ONLY AVAILABLE IN PAID PLANS',
#    'pubDate': '2025-03-05 21:00:16',
#    'pubDateTZ': 'UTC',
#    'image_url': None,
#    'source_id': 'pakobserver',
#    'source_priority': 242935,
#    'source_name': 'Pakistan Observer',
#    'source_url': 'https://pakobserver.net',
#    'source_icon': 'https://i.bytvi.com/domain_icons/pakobserver.jpg',
#    'language': 'english',
#    'country': ['pakistan'],
#    'category': ['top'],
#    'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'duplicate': False},
#   {'article_id': 'e914bd608876d55a97890cd27e0f0996',
#    'title': 'Venture Global Faces Earnings Test After Energy’s Worst Big IPO',
#    'link': 'https://www.livemint.com/companies/venture-global-faces-earnings-test-after-energy-s-worst-big-ipo-11741208271794.html',
#    'keywords': None,
#    'creator': None,
#    'video_url': None,
#    'description': 'Venture Global Inc. is approaching its first corporate earnings call as a public company bearing a dubious distinction: it is the worst-performing large energy IPO in at least the last 30 years.',
#    'content': 'ONLY AVAILABLE IN PAID PLANS',
#    'pubDate': '2025-03-05 20:57:51',
#    'pubDateTZ': 'UTC',
#    'image_url': 'https://www.livemint.com/lm-img/img/2024/12/06/1600x900/company_1_1733464951182_1733464958176.png',
#    'source_id': 'livemint',
#    'source_priority': 7134,
#    'source_name': 'Mint',
#    'source_url': 'https://www.livemint.com',
#    'source_icon': 'https://i.bytvi.com/domain_icons/livemint.png',
#    'language': 'english',
#    'country': ['india'],
#    'category': ['business'],
#    'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'duplicate': False},
#   {'article_id': 'b342d891021926e86dfbdad24c299dcc',
#    'title': 'Kiwis surge into Champions Trophy final as Proteas choke at business end of tournament yet again',
#    'link': 'https://www.theroar.com.au/2025/03/06/kiwis-surge-into-champions-trophy-final-as-proteas-choke-at-business-end-of-tournament-yet-again/',
#    'keywords': ['champions trophy',
#     'cricket',
#     'rachin ravindra',
#     'featured',
#     'kane williamson'],
#    'creator': ['News'],
#    'video_url': None,
#    'description': 'Rachin Ravindra and Kane Williamson have struck superb centuries while captain Mitch Santner was brilliant with the ball as New Zealand earned a handsome 50-run victory over South Africa to earn a final date against India in the Champions Trophy. Ravindra caned 108 off 101 balls and the evergreen Williamson 102 from 94 as the [...]',
#    'content': 'ONLY AVAILABLE IN PAID PLANS',
#    'pubDate': '2025-03-05 20:14:40',
#    'pubDateTZ': 'UTC',
#    'image_url': 'https://cdn4.theroar.com.au/wp-content/uploads/2022/11/Kane-Williamson-New-Zealand-1-1200x675.jpg',
#    'source_id': 'theroar_au',
#    'source_priority': 163462,
#    'source_name': 'The Roar',
#    'source_url': 'https://www.theroar.com.au',
#    'source_icon': 'https://i.bytvi.com/domain_icons/theroar_au.jpg',
#    'language': 'english',
#    'country': ['australia'],
#    'category': ['sports'],
#    'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'duplicate': False},
#   {'article_id': '1c07f01a549465c71b487c1cf6db8573',
#    'title': '"Viola gli accordi". Ferrari fa causa all\'ex Cardile, la decisione può ribaltare il Mondiale di F1',
#    'link': 'https://www.liberoquotidiano.it/news/sport/41787875/ferrari-causa-ex-direttore-tenico-cardile-viola-accordi-non-concorrenza-cosa-deciso-tribunale.html',
#    'keywords': None,
#    'creator': None,
#    'video_url': None,
#    'description': "Enrico Cardile non può lavorare in Aston Martin prima del prossimo 18 luglio. Così ha deciso il tribunale di Modena, accogliendo le richieste della Ferrari e “ordinando a Cardile di cessare ogni forma di collaborazione con l'Aston Martin”. La vittoria nella battaglia legale è dunque del team di Maranello. Il team inglese, con sede a Silverstone, dovrà aspettarlo per l'estate dopo aver appena accolto il genio Adrian Newey, arrivato dalla Red Bull pluricampione del mondo e strappato proprio alla Rossa nel corso della passata stagione. Il trasferimento di Cardile sarebbe dovuto avvenire in questi giorni, prima della decisione del tribunale, che ha dato ragione alla Scuderia. La motivazione è la seguente: “L'ex dipendente stava già violando l'impegno di non concorrenza assunto a favore di Ferrari, il cui scopo era quello di evitare che gli altri team di F1, ingaggiando Cardile prima di quanto consentito, potessero trarre un ingiustificato vantaggio competitivo, causando a Ferrari un pregiudizio irreparabile”. Dunque niente Aston Martin per Cardile (per il momento). Gli inglesi lo avevano già inserito all'interno dell'organigramma nel ruolo di Chief Technical Officer, con l'obiettivo di farlo lavorare ai programmi 2026, già in avanzata fase di definizione, anno del cambio dei regolamenti al motore. Cardile si era dimesso nella scorsa estate, il suo posto in Ferrari è stato preso dal francese Loic Serra, arrivato dalla Mercedes. Dal team delle Frecce d'Argento è arrivato anche Andy Cowell come a.d. della scuderia color green british, che dalla prossima stagione monterà i motori Honda e punta a inserirsi nella lotta Mondiale, anche grazie ai contributi del ricco sponsor Aramco.",
#    'content': 'ONLY AVAILABLE IN PAID PLANS',
#    'pubDate': '2025-03-05 19:53:00',
#    'pubDateTZ': 'UTC',
#    'image_url': 'https://img2.liberoquotidiano.it/images/2025/03/05/125704629-9986b855-97f8-444b-a05f-244bdf1070f7.jpg',
#    'source_id': 'liberoquotidiano',
#    'source_priority': 200706,
#    'source_name': 'Libero Quotidiano',
#    'source_url': 'https://www.liberoquotidiano.it',
#    'source_icon': 'https://i.bytvi.com/domain_icons/liberoquotidiano.jpg',
#    'language': 'italian',
#    'country': ['italy'],
#    'category': ['top'],
#    'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'duplicate': False},
#   {'article_id': 'af7a8a30e34b4d452ffdd4294834ce84',
#    'title': 'La moitié des émissions mondiales de CO2 sont dues à 36 entreprises... pour la plupart publiques',
#    'link': 'https://www.lexpress.fr/environnement/la-moitie-des-emissions-mondiales-de-co2-sont-dues-a-36-entreprises-pour-la-plupart-publiques-42G5PZNOS5GE5A7AMZZYEPEE6Q/',
#    'keywords': None,
#    'creator': None,
#    'video_url': None,
#    'description': None,
#    'content': 'ONLY AVAILABLE IN PAID PLANS',
#    'pubDate': '2025-03-05 18:38:46',
#    'pubDateTZ': 'UTC',
#    'image_url': 'https://www.lexpress.fr/resizer/v2/IJRDZA4HTZAMBCSWGP7M2SYXT4.jpg?auth=8a81eacb1b343cdb475c5177fff360e826d721d34218dbc0eb51a972c8460471&height=5504&smart=true&width=8256',
#    'source_id': 'lexpress_fr',
#    'source_priority': 1003057,
#    'source_name': 'Lexpress Fr',
#    'source_url': 'https://www.lexpress.fr',
#    'source_icon': 'https://i.bytvi.com/domain_icons/lexpress_fr.png',
#    'language': 'french',
#    'country': ['france'],
#    'category': ['environment'],
#    'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'duplicate': False},
#   {'article_id': 'c27598f0e6e4b6b443c86fd06b96855d',
#    'title': 'SA vs NZ, Champions Trophy 2025: Rachin, Williamson hundreds help New Zealand overpower South Africa',
#    'link': 'https://sportstar.thehindu.com/cricket/champions-trophy/south-africa-vs-new-zealand-champions-trophy-2025-semifinal-score-result-match-report-sa-v-nz/article69295785.ece',
#    'keywords': ['champions trophy'],
#    'creator': None,
#    'video_url': None,
#    'description': 'David Miller’s unbeaten century was too little too late as South Africa succumbed to yet another ICC event heartbreak, losing the Champions Trophy semifinal to New Zealand in Lahore.',
#    'content': 'ONLY AVAILABLE IN PAID PLANS',
#    'pubDate': '2025-03-05 17:13:01',
#    'pubDateTZ': 'UTC',
#    'image_url': 'https://ss-i.thgim.com/public/incoming/dg2lym/article69295781.ece/alternates/LANDSCAPE_1200/2025-03-05T104136Z_831401664_UP1EL350TPBU7_RTRMADP_3_CRICKET-CHAMPIONSTROPHY-ZAF-NZL.JPG',
#    'source_id': 'sportstar',
#    'source_priority': 2972,
#    'source_name': 'Sport Star The Hindu',
#    'source_url': 'https://sportstar.thehindu.com',
#    'source_icon': 'https://i.bytvi.com/domain_icons/sportstar.png',
#    'language': 'english',
#    'country': ['india'],
#    'category': ['sports'],
#    'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'duplicate': False},
#   {'article_id': 'e722853fb1904d03a165430e54562dca',
#    'title': 'Middle East Energy Transition: Key Sectors & Companies Driving Decarbonization',
#    'link': 'https://www.globenewswire.com/fr/news-release/2025/03/05/3037638/28124/en/Middle-East-Energy-Transition-Key-Sectors-Companies-Driving-Decarbonization.html',
#    'keywords': None,
#    'creator': None,
#    'video_url': None,
#    'description': 'The Middle East energy transition is accelerating, with renewables projected to account for 14% of power generation by 2035. While fossil fuels remain dominant, investments in solar, CCUS, and hydrogen are expanding, positioning the region as a global low-carbon energy leader. The latest report analyzes market trends, net-zero targets, and major energy players, including Abu Dhabi Power, ACWA Power, Masdar, and Saudi Aramco. With green hydrogen capacity growing at a 150% CAGR and CCUS at 44%, this report offers key insights for businesses navigating the region’s evolving energy landscape. The Middle East energy transition is accelerating, with renewables projected to account for 14% of power generation by 2035. While fossil fuels remain dominant, investments in solar, CCUS, and hydrogen are expanding, positioning the region as a global low-carbon energy leader. The latest report analyzes market trends, net-zero targets, and major energy players, including Abu Dhabi Power, ACWA Power, Masdar, and Saudi Aramco. With green hydrogen capacity growing at a 150% CAGR and CCUS at 44%, this report offers key insights for businesses navigating the region’s evolving energy landscape.',
#    'content': 'ONLY AVAILABLE IN PAID PLANS',
#    'pubDate': '2025-03-05 17:03:00',
#    'pubDateTZ': 'UTC',
#    'image_url': None,
#    'source_id': 'globenewswire_fr',
#    'source_priority': 2056,
#    'source_name': 'Globenewswire_fr',
#    'source_url': 'https://www.globenewswire.com/fr',
#    'source_icon': 'https://i.bytvi.com/domain_icons/globenewswire_fr.jpg',
#    'language': 'english',
#    'country': ['france'],
#    'category': ['science'],
#    'ai_tag': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'sentiment_stats': 'ONLY AVAILABLE IN PROFESSIONAL AND CORPORATE PLANS',
#    'ai_region': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'ai_org': 'ONLY AVAILABLE IN CORPORATE PLANS',
#    'duplicate': False}],
#  'nextPage': '1741194180133016689'}

# %%
import pandas as pd 

df = pd.DataFrame(response['results'])
df
# Out:
#                          article_id  ... duplicate
# 0  db06ee19e65bccbd3d512a4ee38d5e98  ...     False
# 1  da92c4becee4759af5820806ebb4d6dd  ...     False
# 2  5c71b8bc515f2b9d725f1b55fb4b370b  ...     False
# 3  816dbcdd01d45f9b23827329aaa289bb  ...     False
# 4  e914bd608876d55a97890cd27e0f0996  ...     False
# 5  b342d891021926e86dfbdad24c299dcc  ...     False
# 6  1c07f01a549465c71b487c1cf6db8573  ...     False
# 7  af7a8a30e34b4d452ffdd4294834ce84  ...     False
# 8  c27598f0e6e4b6b443c86fd06b96855d  ...     False
# 9  e722853fb1904d03a165430e54562dca  ...     False
#
# [10 rows x 25 columns]
