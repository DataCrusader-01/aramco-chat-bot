# %%
import pywhatkit as kit

# Send an instant message without delay
kit.sendwhatmsg_instantly("+916281432822", "Hello, this is a fast message!")

# %%
import pywhatkit as kit
import time
import pyautogui

# Function to send an instant WhatsApp message
def send_whatsapp_alert(number, message):
    print(f"Sending message to {number}...")
    kit.sendwhatmsg_instantly(number, message, wait_time=5)
    time.sleep(5)  # Wait for WhatsApp to open
    pyautogui.press("enter")  # Press enter to send the message instantly
    print("Message sent successfully!")

# Example: Send a WhatsApp alert
send_whatsapp_alert("+916281432822", "🚨 Alert! This is an automated message.")

# %% [markdown]
# ### latest 1 news article based on keyword

# %%
import requests
import pywhatkit as kit
import time
import pyautogui

# 🔹 Your API Key from NewsAPI.org
NEWS_API_KEY = "5e09c165638e4db88228635ebeccc5f6"

# 🔹 WhatsApp Number (Format: "+CountryCodePhoneNumber")
WHATSAPP_NUMBER = "+916281432822"

# Function to get the latest 1 news article based on keyword
def get_news(keyword, num_articles=1):
    url = f"https://newsapi.org/v2/everything?q={keyword}&sortBy=publishedAt&pageSize={num_articles}&apiKey={NEWS_API_KEY}"
    response = requests.get(url)
    news_data = response.json()
    
    articles = news_data.get("articles", [])[:num_articles]
    if not articles:
        return "⚠️ No latest news found for this keyword."

    # Extract details of the latest news article
    article = articles[0]
    title = article["title"]
    url = article["url"]
    published_at = article["publishedAt"][:10]  # Extracting only the date

    news_summary = f"📰 Latest News on {keyword}:\n\n{title} ({published_at})\n{url}"
    return news_summary

# Function to send WhatsApp Alert
def send_whatsapp_alert(news_message):
    print(f"Sending news alert to {WHATSAPP_NUMBER}...")
    
    kit.sendwhatmsg_instantly(WHATSAPP_NUMBER, news_message, wait_time=5)
    time.sleep(5)
    pyautogui.press("enter")  # Press enter to send
    
    print("News alert sent successfully!")

# 🔹 Keyword for news search (Change as needed)
keyword = "Elon Musk"

# 🔹 Fetch the latest 1 news article
news_summary = get_news(keyword)

# 🔹 Send WhatsApp Alert
send_whatsapp_alert(news_summary)

# %% [markdown]
# ### Updated Python Script: Send Last 10 News Articles One by One

# %%
import requests
import pywhatkit as kit
import time
import pyautogui

#  Your API Key from NewsAPI.org
NEWS_API_KEY = "5e09c165638e4db88228635ebeccc5f6"

# 🔹 WhatsApp Number (Format: "+CountryCodePhoneNumber")
WHATSAPP_NUMBER = "+916281432822"

# Function to get the latest 10 news articles based on keyword
def get_news(keyword, num_articles=10):
    url = f"https://newsapi.org/v2/everything?q={keyword}&sortBy=publishedAt&pageSize={num_articles}&apiKey={NEWS_API_KEY}"
    response = requests.get(url)
    news_data = response.json()
    
    articles = news_data.get("articles", [])[:num_articles]
    if not articles:
        return ["⚠️ No latest news found for this keyword."]

    news_list = []
    for idx, article in enumerate(articles):
        title = article["title"]
        url = article["url"]
        published_at = article["publishedAt"][:10]  # Extracting only the date
        news_list.append(f"📰 News {idx+1} on {keyword}:\n\n{title} ({published_at})\n{url}")

    return news_list

# Function to send WhatsApp alerts quickly (without reopening WhatsApp Web)
def send_whatsapp_alert(news_list):
    print(f"Opening WhatsApp Web and preparing to send messages to {WHATSAPP_NUMBER}...")

    # Open WhatsApp Web immediately & send the first message
    kit.sendwhatmsg_instantly(WHATSAPP_NUMBER, news_list[0], wait_time=5)
    print("WhatsApp Web opened instantly! Sending first message...")

    time.sleep(5)  # Wait a few seconds for the message to be ready
    pyautogui.press("enter")  # Press enter to send first message

    # Send remaining messages with only a 5-second delay
    for idx, news_message in enumerate(news_list[1:], start=2):
        print(f"Sending News {idx}...")

        time.sleep(5)  # Reduce wait time to just 5 seconds
        pyautogui.typewrite(news_message)  # Type message
        pyautogui.press("enter")  # Press enter to send

        print(f"News {idx} sent successfully! Waiting 5 seconds before next...")

# 🔹 Keyword for news search (Change as needed)
keyword = "Elon Musk"

# 🔹 Fetch the latest 10 news articles
news_list = get_news(keyword)

# 🔹 Send all news articles quickly in one WhatsApp Web session
send_whatsapp_alert(news_list)

# %%
import requests
from dotenv import load_dotenv

load_dotenv()

# WhatsApp API Credentials
WHATSAPP_TOKEN = "EAAHNqC4eiEoBO1z3SXzYB8PZBGyW0Hq3qnEgSoEiZCKVSfRizQMKmOXJq6GlvYpoTt10j3WtjwsBhZA4j2YA4zBdMPmVRZBhZAbcaxZCTlzHK1zKyYfR9SZC4ZCDZAq5Nkgu3jJCunCtSsNJOTfSyIkVCNqw23tp4bg4Otd8OAXkWnragHRwWb0gkM3Oqe9bC9YFhqj5TNDcROLcgiv3waw7bDAv78q1ZCZAG4KStsZD"
PHONE_NUMBER = "916281432822"
PHONE_NUMBER_ID = "471691732693814"
GRAPH_API_VERSION = "v21.0"
BASE_URL = f"https://graph.facebook.com/{GRAPH_API_VERSION}/{PHONE_NUMBER_ID}/messages"

# Your API Key from NewsAPI.org
NEWS_API_KEY = "5e09c165638e4db88228635ebeccc5f6"

# Function to fetch the latest news
def get_news(keyword, num_articles=5):
    url = f"https://newsapi.org/v2/everything?q={keyword}&sortBy=publishedAt&pageSize={num_articles}&apiKey={NEWS_API_KEY}"
    response = requests.get(url)
    news_data = response.json()

    articles = news_data.get("articles", [])[:num_articles]
    if not articles:
        return ["⚠️ No latest news found for this keyword."]

    news_list = []
    for idx, article in enumerate(articles):
        title = article["title"]
        url = article["url"]
        news_list.append((title, url))

    return news_list


# Function to send news via WhatsApp API
def send_news_template(news_title, news_url):
    headers = {
        "Authorization": f"Bearer {WHATSAPP_TOKEN}",
        "Content-Type": "application/json"
    }

    # Use correct template (must be approved)
    TEMPLATE_NAME = "news_alert"  # Replace with approved template

    data = {
        "messaging_product": "whatsapp",
        "to": PHONE_NUMBER,
        "type": "template",
        "template": {
            "name": TEMPLATE_NAME,
            "language": {"code": "en_US"},
            "components": [
                {
                    "type": "body",
                    "parameters": [
                        {"type": "text", "text": news_title},
                        {"type": "text", "text": news_url}
                    ]
                }
            ]
        }
    }

    response = requests.post(BASE_URL, json=data, headers=headers)

    print("\n--- News Sent ---")
    print("Status Code:", response.status_code)
    print("Response:", response.json())


# 🔹 Fetch and send news
keyword = "Elon Musk"
news_list = get_news(keyword)

for news_title, news_url in news_list:
    send_news_template(news_title, news_url)
# Out:
# --- News Sent ---
# Status Code: 404
# Response: {'error': {'message': '(#132001) Template name does not exist in the translation', 'type': 'OAuthException', 'code': 132001, 'error_data': {'messaging_product': 'whatsapp', 'details': 'template name (news_alert) does not exist in en_US'}, 'fbtrace_id': 'A95xYcY-PwHFpiTJN2fkyaO'}}
#
# --- News Sent ---
# Status Code: 404
# Response: {'error': {'message': '(#132001) Template name does not exist in the translation', 'type': 'OAuthException', 'code': 132001, 'error_data': {'messaging_product': 'whatsapp', 'details': 'template name (news_alert) does not exist in en_US'}, 'fbtrace_id': 'ARdTvYSWDEB9llsS3A-cqZb'}}
#
# --- News Sent ---
# Status Code: 404
# Response: {'error': {'message': '(#132001) Template name does not exist in the translation', 'type': 'OAuthException', 'code': 132001, 'error_data': {'messaging_product': 'whatsapp', 'details': 'template name (news_alert) does not exist in en_US'}, 'fbtrace_id': 'AU6CvAbbzdVyK3-uUeXixs5'}}
# ...

# %%
import requests

# ✅ Replace with your actual credentials
WHATSAPP_TOKEN = "EAAHNqC4eiEoBOyfW5OgLUyoMX2m0dR7RC9bcfdb3eTg1Mt5BiVXZCA1GCUafW9IKd5z0s6OesLxqCpWfkkiVbs0FTwMoxSM5NN1bizb34Dzrdwju3ONnsWuAscSWn6jwfll9CNofkWsSwGkT4bYOx87cIOvS1plnZAZAAZAW4AtplvDd08FrLfq35jyaAPBzZCMUE7BDisjyjj6f5goUL7Xibcswv8u5jUJ0ZD"
PHONE_NUMBER = "916281432822"  # Receiver's WhatsApp number
PHONE_NUMBER_ID = "587537381107444"  # ✅ Your WhatsApp Phone Number ID
BASE_URL = f"https://graph.facebook.com/v21.0/{PHONE_NUMBER_ID}/messages"
NEWS_API_KEY = "5e09c165638e4db88228635ebeccc5f6"

# 🔹 Function to fetch the latest news article
def get_news(keyword, num_articles=1):
    url = f"https://newsapi.org/v2/everything?q={keyword}&sortBy=publishedAt&pageSize={num_articles}&apiKey={NEWS_API_KEY}"
    response = requests.get(url)
    news_data = response.json()

    articles = news_data.get("articles", [])[:num_articles]
    if not articles:
        return None

    first_article = articles[0]
    title = first_article["title"]
    description = first_article.get("description", "No description available.")
    article_url = first_article["url"]
    
    return title, description, article_url

# 🔹 Function to send WhatsApp news alert using the template
def send_news_alert():
    news_data = get_news("technology", 1)  # ✅ Change keyword as needed

    if not news_data:
        print("No latest news found.")
        return

    title, description, article_url = news_data

    headers = {
        "Authorization": f"Bearer {WHATSAPP_TOKEN}",
        "Content-Type": "application/json"
    }

    # ✅ WhatsApp message template payload
    data = {
        "messaging_product": "whatsapp",
        "to": PHONE_NUMBER,
        "type": "template",
        "template": {
            "name": "news_alert",  # ✅ Ensure this template is approved in WhatsApp Manager
            "language": {"code": "en_US"},
            "components": [
                {
                    "type": "body",
                    "parameters": [
                        {"type": "text", "text": title},          # {{1}} - News headline
                        {"type": "text", "text": description}    # {{2}} - News description
                    ]
                },
                {
                    "type": "button",
                    "sub_type": "url",
                    "index": 0,
                    "parameters": [
                        {"type": "text", "text": article_url}    # ✅ Corrected Button URL
                    ]
                }
            ]
        }
    }

    # ✅ Sending request to WhatsApp API
    response = requests.post(BASE_URL, json=data, headers=headers)

    # ✅ Printing response details
    print("\n--- News Sent ---")
    print("Status Code:", response.status_code)
    print("Response:", response.json())

# 🔹 Run the function to send news alert
send_news_alert()
# Out:
# --- News Sent ---
# Status Code: 400
# Response: {'error': {'message': "Unsupported post request. Object with ID '587537381107444' does not exist, cannot be loaded due to missing permissions, or does not support this operation. Please read the Graph API documentation at https://developers.facebook.com/docs/graph-api", 'type': 'GraphMethodException', 'code': 100, 'error_subcode': 33, 'fbtrace_id': 'A8TUShMAfgX1Zbb441RpvFa'}}

# %% [markdown]
# ### WhatsApp Business API

# %%
import requests
import time

# 🔹 Your API Key from NewsAPI.org
NEWS_API_KEY = "5e09c165638e4db88228635ebeccc5f6"

# 🔹 WhatsApp Business API Token
WHATSAPP_API_KEY = "EAAHNqC4eiEoBOZBZAvFZARrd7taLwgMhw9JbhE291B7WEKT966On4Tga94a6zZBCvsIf7vwOqkPQmXb65KtoZAlOcipWFlk6Cp6C9CF1UMPWrb9q852AmBXniXEinfSVQOcbZBbOjDm6pFcX3B0eZCZASqwUHv7hogWKa2ZA4ukBMpZCU4lgDZA2yEZACxLTObNAZCgREO5i6AQbNTIIAYrM2JPhDiyRhU1g4lyUPjoEZD"

# 🔹 Your WhatsApp Business Number ID
WHATSAPP_PHONE_NUMBER_ID = "587537381107444"

# 🔹 Recipient WhatsApp Number (Format: "91XXXXXXXXXX")
RECIPIENT_NUMBER = "916281432822"

# Function to get the latest 10 news articles based on keyword
def get_news(keyword, num_articles=10):
    url = f"https://newsapi.org/v2/everything?q={keyword}&sortBy=publishedAt&pageSize={num_articles}&apiKey={NEWS_API_KEY}"
    response = requests.get(url)
    news_data = response.json()
    
    articles = news_data.get("articles", [])[:num_articles]
    if not articles:
        return ["⚠️ No latest news found for this keyword."]

    news_list = []
    for idx, article in enumerate(articles):
        title = article["title"]
        url = article["url"]
        published_at = article["publishedAt"][:10]  # Extracting only the date
        news_list.append(f"📰 News {idx+1} on {keyword}:\n\n{title} ({published_at})\n{url}")

    return news_list

# Function to send WhatsApp message using API
def send_whatsapp_message(message):
    url = f"https://graph.facebook.com/v18.0/{WHATSAPP_PHONE_NUMBER_ID}/messages"
    
    headers = {
        "Authorization": f"Bearer {WHATSAPP_API_KEY}",
        "Content-Type": "application/json"
    }
    
    payload = {
        "messaging_product": "whatsapp",
        "to": RECIPIENT_NUMBER,
        "type": "text",
        "text": {"body": message}
    }
    
    response = requests.post(url, headers=headers, json=payload)
    
    if response.status_code == 200:
        print("✅ Message sent successfully!")
    else:
        print(f"⚠️ Failed to send message. Response: {response.json()}")

# 🔹 Keyword for news search
keyword = "Elon Musk"

# 🔹 Fetch the latest 10 news articles
news_list = get_news(keyword)

# 🔹 Send all news articles via WhatsApp API
for idx, news in enumerate(news_list):
    print(f"📤 Sending News {idx+1} to WhatsApp...")
    send_whatsapp_message(news)
    time.sleep(5)  # Wait 5 seconds before sending the next message
# Out:
# 📤 Sending News 1 to WhatsApp...
# ⚠️ Failed to send message. Response: {'error': {'message': "Unsupported post request. Object with ID '587537381107444' does not exist, cannot be loaded due to missing permissions, or does not support this operation. Please read the Graph API documentation at https://developers.facebook.com/docs/graph-api", 'type': 'GraphMethodException', 'code': 100, 'error_subcode': 33, 'fbtrace_id': 'AptWYE8gZ3PC2_8Hufc0jw5'}}
# 📤 Sending News 2 to WhatsApp...
# ⚠️ Failed to send message. Response: {'error': {'message': "Unsupported post request. Object with ID '587537381107444' does not exist, cannot be loaded due to missing permissions, or does not support this operation. Please read the Graph API documentation at https://developers.facebook.com/docs/graph-api", 'type': 'GraphMethodException', 'code': 100, 'error_subcode': 33, 'fbtrace_id': 'AWBk87SjbCwwBTR_Eo9WDCQ'}}
# 📤 Sending News 3 to WhatsApp...
# ...

# %%
import requests

# 🔹 Your API Credentials
ACCESS_TOKEN = "EAAHNqC4eiEoBO7gqWuhgPZBXFIbV3tHndJuo3VFYxZCNBb5mNHq57V015K4N1z4sVYZB0PWkYpz68qa1UqEjWIiHHZCQWlZCZCZCrwrU66tlf8L1Jp7BIEWwFzFgrqEKPm92WaOkvIuH0CxlkO6xSf65ASZCvgq4t0eee7livOHrQiO767JgVsZA1Bm23mphk1xmUJawFBn3Ww3JnBZCWgobkaSrsbE3h8OsJl8ZCUI"
PHONE_NUMBER_ID = "587537381107444"  # Your WhatsApp Phone Number ID
RECIPIENT_NUMBER = "916281432822"  # Replace with the recipient's phone number (without '+')

# 🔹 API Endpoint
url = f"https://graph.facebook.com/v18.0/{PHONE_NUMBER_ID}/messages"

# 🔹 Headers
headers = {
    "Authorization": f"Bearer {ACCESS_TOKEN}",
    "Content-Type": "application/json"
}

# 🔹 Message Payload
data = {
    "messaging_product": "whatsapp",
    "to": RECIPIENT_NUMBER,
    "type": "text",
    "text": {"body": "Hello! This is a test message from WhatsApp Cloud AP."}
}

# 🔹 Sending the Request
response = requests.post(url, headers=headers, json=data)

# 🔹 Output Response
print(response.json())  # Check API response for errors
# Out:
# {'error': {'message': "Unsupported post request. Object with ID '587537381107444' does not exist, cannot be loaded due to missing permissions, or does not support this operation. Please read the Graph API documentation at https://developers.facebook.com/docs/graph-api", 'type': 'GraphMethodException', 'code': 100, 'error_subcode': 33, 'fbtrace_id': 'Az4gnPpD4MyVYVO2wU8Pisu'}}

# %%
import requests

# WhatsApp API Credentials
ACCESS_TOKEN = "EAAHNqC4eiEoBO7gqWuhgPZBXFIbV3tHndJuo3VFYxZCNBb5mNHq57V015K4N1z4sVYZB0PWkYpz68qa1UqEjWIiHHZCQWlZCZCZCrwrU66tlf8L1Jp7BIEWwFzFgrqEKPm92WaOkvIuH0CxlkO6xSf65ASZCvgq4t0eee7livOHrQiO767JgVsZA1Bm23mphk1xmUJawFBn3Ww3JnBZCWgobkaSrsbE3h8OsJl8ZCUI"
PHONE_NUMBER_ID = "471691732693814"  # Your WhatsApp Business API Phone Number ID
TO_PHONE_NUMBER = "916281432822"  # Recipient's phone number

# WhatsApp Cloud API URL
url = f"https://graph.facebook.com/v21.0/{PHONE_NUMBER_ID}/messages"

# Headers
headers = {
    "Authorization": f"Bearer {ACCESS_TOKEN}",
    "Content-Type": "application/json"
}

# JSON Data (Using an approved template message)
data = {
    "messaging_product": "whatsapp",
    "to": TO_PHONE_NUMBER,
    "type": "template",
    "template": {
        "name": "hello_world",  # This must match an approved template name
        "language": {"code": "en_US"}
    }
}

# Send request
response = requests.post(url, json=data, headers=headers)

# Print response
print(response.status_code, response.json())
# Out:
# 200 {'messaging_product': 'whatsapp', 'contacts': [{'input': '916281432822', 'wa_id': '916281432822'}], 'messages': [{'id': 'wamid.HBgMOTE2MjgxNDMyODIyFQIAERgSQ0FBRjhDREVFRDU5RTBENkYyAA==', 'message_status': 'accepted'}]}

# %%
import requests
import time

# 🔹 API Keys
NEWS_API_KEY = "5e09c165638e4db88228635ebeccc5f6"  # Your NewsAPI Key
WHATSAPP_API_KEY = "EAAHNqC4eiEoBO7gqWuhgPZBXFIbV3tHndJuo3VFYxZCNBb5mNHq57V015K4N1z4sVYZB0PWkYpz68qa1UqEjWIiHHZCQWlZCZCZCrwrU66tlf8L1Jp7BIEWwFzFgrqEKPm92WaOkvIuH0CxlkO6xSf65ASZCvgq4t0eee7livOHrQiO767JgVsZA1Bm23mphk1xmUJawFBn3Ww3JnBZCWgobkaSrsbE3h8OsJl8ZCUI"

# 🔹 WhatsApp API Details
WHATSAPP_PHONE_NUMBER_ID = "471691732693814"  # Your WhatsApp Business API Phone Number ID
RECIPIENT_NUMBER = "916281432822"  # Recipient's WhatsApp number

# 🔹 Function to Get Latest 10 News Articles
def get_news(keyword, num_articles=10):
    url = f"https://newsapi.org/v2/everything?q={keyword}&sortBy=publishedAt&pageSize={num_articles}&apiKey={NEWS_API_KEY}"
    response = requests.get(url)
    news_data = response.json()

    articles = news_data.get("articles", [])[:num_articles]
    if not articles:
        return ["⚠️ No latest news found for this keyword."]

    news_list = []
    for idx, article in enumerate(articles):
        title = article["title"]
        news_url = article["url"]
        published_at = article["publishedAt"][:10]  # Extract only the date
        news_list.append(f"📰 News {idx+1} on {keyword}:\n\n{title} ({published_at})\n{news_url}")

    return news_list

# 🔹 Function to Send WhatsApp Message using API
def send_whatsapp_message(message):
    url = f"https://graph.facebook.com/v21.0/{WHATSAPP_PHONE_NUMBER_ID}/messages"

    headers = {
        "Authorization": f"Bearer {WHATSAPP_API_KEY}",
        "Content-Type": "application/json"
    }

    payload = {
        "messaging_product": "whatsapp",
        "to": RECIPIENT_NUMBER,
        "type": "text",
        "text": {"body": message}
    }

    response = requests.post(url, headers=headers, json=payload)

    if response.status_code == 200:
        print("✅ Message sent successfully!")
    else:
        print(f"⚠️ Failed to send message. Response: {response.json()}")

# 🔹 Fetch News & Send via WhatsApp API
if __name__ == "__main__":
    keyword = "Elon Musk"  # Change keyword as needed

    print(f"🔍 Fetching latest news on '{keyword}'...")
    news_list = get_news(keyword)

    for idx, news in enumerate(news_list):
        print(f"📤 Sending News {idx+1} to WhatsApp...")
        send_whatsapp_message(news)
        time.sleep(5)  # Wait 5 seconds before sending the next message
# Out:
# 🔍 Fetching latest news on 'Elon Musk'...
# 📤 Sending News 1 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 2 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 3 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 4 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 5 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 6 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 7 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 8 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 9 to WhatsApp...
# ✅ Message sent successfully!

# %%
import requests
import time

# 👉 API Keys
NEWS_API_KEY = "5e09c165638e4db88228635ebeccc5f6"  # Your NewsAPI Key
WHATSAPP_API_KEY = "EAAHNqC4eiEoBOZBZAvFZARrd7taLwgMhw9JbhE291B7WEKT966On4Tga94a6zZBCvsIf7vwOqkPQmXb65KtoZAlOcipWFlk6Cp6C9CF1UMPWrb9q852AmBXniXEinfSVQOcbZBbOjDm6pFcX3B0eZCZASqwUHv7hogWKa2ZA4ukBMpZCU4lgDZA2yEZACxLTObNAZCgREO5i6AQbNTIIAYrM2JPhDiyRhU1g4lyUPjoEZD"

# 👉 WhatsApp API Details
PHONE_NUMBER_ID = "471691732693814"  # Your WhatsApp Business API Phone Number ID
RECIPIENT_NUMBER = "916281432822"  # Recipient's WhatsApp number

# 👉 WhatsApp Cloud API URL
WHATSAPP_API_URL = f"https://graph.facebook.com/v21.0/{PHONE_NUMBER_ID}/messages"

# 👉 Function to Get Latest 10 News Articles
def get_news(keyword, num_articles=10):
    url = f"https://newsapi.org/v2/everything?q={keyword}&sortBy=publishedAt&pageSize={num_articles}&apiKey={NEWS_API_KEY}"
    response = requests.get(url)
    news_data = response.json()

    articles = news_data.get("articles", [])[:num_articles]
    if not articles:
        return ["⚠️ No latest news found for this keyword."]

    news_list = []
    for idx, article in enumerate(articles):
        title = article["title"]
        news_url = article["url"]
        published_at = article["publishedAt"][:10]  # Extract only the date
        news_list.append(f"📰 News {idx+1} on {keyword}:\n\n{title} ({published_at})\n{news_url}")

    return news_list

# 👉 Function to Send WhatsApp Message using API
def send_whatsapp_message(message):
    headers = {
        "Authorization": f"Bearer {WHATSAPP_API_KEY}",
        "Content-Type": "application/json"
    }

    payload = {
        "messaging_product": "whatsapp",
        "to": RECIPIENT_NUMBER,
        "type": "text",
        "text": {"body": message}
    }

    response = requests.post(WHATSAPP_API_URL, headers=headers, json=payload)

    if response.status_code == 200:
        print("✅ Message sent successfully!")
    else:
        print(f"⚠️ Failed to send message. Response: {response.json()}")

# 👉 Fetch News & Send via WhatsApp API
if __name__ == "__main__":
    keyword = "Elon Musk"  # Change keyword as needed

    print(f"🔍 Fetching latest news on '{keyword}'...")
    news_list = get_news(keyword)

    for idx, news in enumerate(news_list):
        print(f"📤 Sending News {idx+1} to WhatsApp...")
        send_whatsapp_message(news)
        time.sleep(5)  # Wait 5 seconds before sending the next message
# Out:
# 🔍 Fetching latest news on 'Elon Musk'...
# 📤 Sending News 1 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 2 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 3 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 4 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 5 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 6 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 7 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 8 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 9 to WhatsApp...
# ✅ Message sent successfully!
# 📤 Sending News 10 to WhatsApp...
# ✅ Message sent successfully!

# %%
import os
import requests
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

WHATSAPP_TOKEN = "EAAHNqC4eiEoBOxurV0i5oK9hYsVymMF6ZB73dzGOgs8vYicPF4cKTHx9OcZAAUWZB9Vh7RcQmoVlIYdeOxUZCkUJCMe5RGwpECqiyonNbMczUxgfReh0avcxOQ9DwYfQVIhs1qRo58A8vwQ0RoblkPX26TpZBEhk1TyyRyxSNNknoBBkLycvlbwCXyluKZBy67okkY1AGrGGuwkHOD9DthVNAuemqb0GznYCC5"
PHONE_NUMBER = "916281432822"
PHONE_NUMBER_ID = "587537381107444"
GRAPH_API_VERSION = "v21.0"
BASE_URL = f"https://graph.facebook.com/{GRAPH_API_VERSION}/{PHONE_NUMBER_ID}/messages"

# Send Template Message
def send_template_message():
    headers = {
        "Authorization": f"Bearer {WHATSAPP_TOKEN}",
        "Content-Type": "application/json"
    }
    data = {
        "messaging_product": "whatsapp",
        "to": PHONE_NUMBER,
        "type": "template",
        "template": {
            "name": "discount",
            "language": {"code": "en_US"},
            "components": [
                {
                    "type": "header",
                    "parameters": [{"type": "text", "text": "John Doe"}]
                },
                {
                    "type": "body",
                    "parameters": [{"type": "text", "text": "50"}]
                }
            ]
        }
    }
    response = requests.post(BASE_URL, json=data, headers=headers)
    print(response.json())


# Uncomment the function you want to test
# send_template_message()
# send_text_message()
# send_media_message()
# upload_image()

# %%
WHATSAPP_TOKEN = "EAAHNqC4eiEoBO1z3SXzYB8PZBGyW0Hq3qnEgSoEiZCKVSfRizQMKmOXJq6GlvYpoTt10j3WtjwsBhZA4j2YA4zBdMPmVRZBhZAbcaxZCTlzHK1zKyYfR9SZC4ZCDZAq5Nkgu3jJCunCtSsNJOTfSyIkVCNqw23tp4bg4Otd8OAXkWnragHRwWb0gkM3Oqe9bC9YFhqj5TNDcROLcgiv3waw7bDAv78q1ZCZAG4KStsZD"
PHONE_NUMBER = "916281432822"

def send_template_message():
    headers = {
        "Authorization": f"Bearer {WHATSAPP_TOKEN}",
        "Content-Type": "application/json"
    }
    data = {
        "messaging_product": "whatsapp",
        "to": PHONE_NUMBER,
        "type": "template",
        "template": {
            "name": "discount",  # Ensure this is an approved template
            "language": {"code": "en_US"},
            "components": [
                {
                    "type": "header",
                    "parameters": [{"type": "text", "text": "John Doe"}]
                },
                {
                    "type": "body",
                    "parameters": [{"type": "text", "text": "50"}]
                }
            ]
        }
    }
    response = requests.post(BASE_URL, json=data, headers=headers)

    print("Status Code:", response.status_code)
    print("Response:", response.json())

# Run the function
send_template_message()
# Out:
# Status Code: 400
# Response: {'error': {'message': "Unsupported post request. Object with ID '587537381107444' does not exist, cannot be loaded due to missing permissions, or does not support this operation. Please read the Graph API documentation at https://developers.facebook.com/docs/graph-api", 'type': 'GraphMethodException', 'code': 100, 'error_subcode': 33, 'fbtrace_id': 'AvEwnDwLJKmquXGBn1WH9bX'}}

# %% [markdown]
# ### working for template

# %%
import os
import requests

# Your API credentials
WHATSAPP_TOKEN = "EAAHNqC4eiEoBO1z3SXzYB8PZBGyW0Hq3qnEgSoEiZCKVSfRizQMKmOXJq6GlvYpoTt10j3WtjwsBhZA4j2YA4zBdMPmVRZBhZAbcaxZCTlzHK1zKyYfR9SZC4ZCDZAq5Nkgu3jJCunCtSsNJOTfSyIkVCNqw23tp4bg4Otd8OAXkWnragHRwWb0gkM3Oqe9bC9YFhqj5TNDcROLcgiv3waw7bDAv78q1ZCZAG4KStsZD"
PHONE_NUMBER = "916281432822"
PHONE_NUMBER_ID = "471691732693814"
GRAPH_API_VERSION = "v21.0"
BASE_URL = f"https://graph.facebook.com/{GRAPH_API_VERSION}/{PHONE_NUMBER_ID}/messages"

# Function to send "hello_world" template
def send_hello_world_template():
    headers = {
        "Authorization": f"Bearer {WHATSAPP_TOKEN}",
        "Content-Type": "application/json"
    }
    data = {
        "messaging_product": "whatsapp",
        "to": PHONE_NUMBER,
        "type": "template",
        "template": {
            "name": "hello_world",  # ✅ Ensure this template is approved
            "language": {"code": "en_US"}
        }
    }
    response = requests.post(BASE_URL, json=data, headers=headers)
    
    print("\n--- Hello World Template ---")
    print("Status Code:", response.status_code)
    print("Response:", response.json())

# Function to send a text message
def send_text_message():
    headers = {
        "Authorization": f"Bearer {WHATSAPP_TOKEN}",
        "Content-Type": "application/json"
    }
    data = {
        "messaging_product": "whatsapp",
        "to": PHONE_NUMBER,
        "type": "text",
        "text": {"body": "This is the text message"}  # ✅ Your custom text message
    }
    response = requests.post(BASE_URL, json=data, headers=headers)

    print("\n--- Text Message ---")
    print("Status Code:", response.status_code)
    print("Response:", response.json())


# Run the functions
send_hello_world_template()  # Sends "hello_world" template
send_text_message()  # Sends a text message
# Out:
# --- Hello World Template ---
# Status Code: 200
# Response: {'messaging_product': 'whatsapp', 'contacts': [{'input': '916281432822', 'wa_id': '916281432822'}], 'messages': [{'id': 'wamid.HBgMOTE2MjgxNDMyODIyFQIAERgSQTMyODJDOEY1NkFEMTdGQ0U4AA==', 'message_status': 'accepted'}]}
#
# --- Text Message ---
# Status Code: 200
# Response: {'messaging_product': 'whatsapp', 'contacts': [{'input': '916281432822', 'wa_id': '916281432822'}], 'messages': [{'id': 'wamid.HBgMOTE2MjgxNDMyODIyFQIAERgSMUJGMjZERTJERkU1RjkyMTY4AA=='}]}

# %%
import os
import requests

# Your API credentials
WHATSAPP_TOKEN = "EAAHNqC4eiEoBO1z3SXzYB8PZBGyW0Hq3qnEgSoEiZCKVSfRizQMKmOXJq6GlvYpoTt10j3WtjwsBhZA4j2YA4zBdMPmVRZBhZAbcaxZCTlzHK1zKyYfR9SZC4ZCDZAq5Nkgu3jJCunCtSsNJOTfSyIkVCNqw23tp4bg4Otd8OAXkWnragHRwWb0gkM3Oqe9bC9YFhqj5TNDcROLcgiv3waw7bDAv78q1ZCZAG4KStsZD"
PHONE_NUMBER = "916281432822"
PHONE_NUMBER_ID = "471691732693814"
GRAPH_API_VERSION = "v21.0"
BASE_URL = f"https://graph.facebook.com/{GRAPH_API_VERSION}/{PHONE_NUMBER_ID}/messages"

# Function to send a template message
def send_template_message():
    headers = {
        "Authorization": f"Bearer {WHATSAPP_TOKEN}",
        "Content-Type": "application/json"
    }
    data = {
        "messaging_product": "whatsapp",
        "to": PHONE_NUMBER,
        "type": "template",
        "template": {
            "name": "hello_world",  # ✅ Ensure this template is approved in Meta Developer Console
            "language": {"code": "en_US"}
        }
    }
    response = requests.post(BASE_URL, json=data, headers=headers)

    print("Status Code:", response.status_code)
    print("Response:", response.json())

# Run the function to send a message
send_template_message()
# Out:
# Status Code: 200
# Response: {'messaging_product': 'whatsapp', 'contacts': [{'input': '916281432822', 'wa_id': '916281432822'}], 'messages': [{'id': 'wamid.HBgMOTE2MjgxNDMyODIyFQIAERgSNUZGQTJGNUI2MkFFMTk4OEFDAA==', 'message_status': 'accepted'}]}

# %% [markdown]
# ### top 10 news articles based on keyword

# %%
import requests
import pywhatkit as kit
import time
import pyautogui

# 🔹 Your API Key from NewsAPI.org
NEWS_API_KEY = "5e09c165638e4db88228635ebeccc5f6"

# 🔹 WhatsApp Number (Format: "+CountryCodePhoneNumber")
WHATSAPP_NUMBER = "+916281432822"

# Function to get top 10 news articles based on keyword
def get_news(keyword, num_articles=10):
    url = f"https://newsapi.org/v2/everything?q={keyword}&sortBy=publishedAt&pageSize={num_articles}&apiKey={NEWS_API_KEY}"
    response = requests.get(url)
    news_data = response.json()
    
    articles = news_data.get("articles", [])[:num_articles]
    news_list = []
    
    for idx, article in enumerate(articles):
        title = article["title"]
        url = article["url"]
        published_at = article["publishedAt"][:10]  # Extracting only the date
        news_list.append(f"{idx+1}. {title} ({published_at})\n{url}")

    if len(news_list) < num_articles:
        news_list.append(f"\n⚠️ Only {len(news_list)} news articles found for '{keyword}'. Expected 10.")

    return "\n\n".join(news_list) if news_list else "No news articles found."

# Function to send WhatsApp Alert
def send_whatsapp_alert(news_message):
    print(f"Sending news alert to {WHATSAPP_NUMBER}...")
    
    # Splitting message if it's too long for WhatsApp
    max_length = 2000  # WhatsApp message limit
    if len(news_message) > max_length:
        parts = [news_message[i:i+max_length] for i in range(0, len(news_message), max_length)]
        for part in parts:
            kit.sendwhatmsg_instantly(WHATSAPP_NUMBER, part, wait_time=5)
            time.sleep(5)
            pyautogui.press("enter")  # Press enter to send
    else:
        kit.sendwhatmsg_instantly(WHATSAPP_NUMBER, news_message, wait_time=5)
        time.sleep(5)
        pyautogui.press("enter")  # Press enter to send
    
    print("News alert sent successfully!")

# 🔹 Keyword for news search (Change as needed)
keyword = "Elon Musk"

# 🔹 Fetch latest 10 news articles
news_summary = get_news(keyword)

# 🔹 Send WhatsApp Alert
if news_summary:
    send_whatsapp_alert(f"📰 Latest 10 News on {keyword}:\n\n{news_summary}")
else:
    send_whatsapp_alert(f"⚠️ No news found on '{keyword}'. Try a different keyword.")
